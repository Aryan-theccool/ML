# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryan-theccool/ML/blob/main/Copy_of_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024

# %% [markdown]
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
def funct1():
  print("hello")
funct1()
# Out:
# hello

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
def funct1(fname):
  print(fname)
funct1("fchchg")
# Out:
# fchchg

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
def funct1(fname, lname ):
  print(fname + "  " +lname)
funct1("fchchg", "vsdvhsg")
# Out:
# fchchg  vsdvhsg

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
def funct1(*kid):
  print(kid[2])
funct1("a", "b", "c")
funct1("a", "b", "r", "d")
funct1("a", "b", "t", "d", "e")
# Out:
# c
# r
# t

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
def funct1( k,j,i):
  print(" the values of i = {}, j={}, k={}" .format(i,j,k))

funct1(i=2, j=6, k=8)
# Out:
#  the values of i = 2, j=6, k=8

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
def funct1( ** var):
   print(var["i"])
funct1(i=2, j=6, k=8)
# Out:
# 2

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
def funct1(food):
  for i in food:
    print(i)

fruits=["apple", "banana", "cherry"]
funct1(fruits)
# Out:
# apple
# banana
# cherry

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
def funct1 (country='India'):
  print ("my country name is " + country)
funct1("newyork")
funct1()
# Out:
# my country name is newyork
# my country name is India

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
def funct1 (x):
  return 5*x

print(funct1(5))
# Out:
# 25

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
def funct1 ():
  pass

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
x=10
def funct1():
  x=10
  x= x*10
  print(x)

funct1()
print(x)
# Out:
# 100
# 10

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
x=10
def funct1():
  x=globals()['x']
  x=10
  x= x*10
  globals()['x']=x
  print(x)

funct1()
print(x)
# Out:
# 100
# 100

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
x=10
def funct1():
  global x
  x= x*100
  print(x)

funct1()
print(x)
# Out:
# 1000
# 1000

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
# explicitly float accept  what to do
def greet(name:float):
  print(type(name))
greet(1234)
greet("welcome")
# Out:
# <class 'int'>
# <class 'str'>

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
num= input("enter a number")
num

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
str= input("enter a string"). split(",")
# Out:
# enter a stringmy, vandana  is a teacher

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
str
# Out:
# ['my', ' vandana  is a teacher']

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
print(1,2,3,4)
# Out:
# 1 2 3 4

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
print(1,2,3,4, sep='*')
# Out:
# 1*2*3*4

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
print(1,2,3,4, sep='*' ,end= '&')
print(1,2,3,4, sep='*')
# Out:
# 1*2*3*4&1*2*3*4

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
x=3;y=4
print( "vcnsv{1}jhsjhd{0}" . format(x,y))
# Out:
# vcnsv4jhsjhd3

# %%
# Name - Aryan Singh Bhadoria
# Roll no. - 0827CI231024
print( "{}jghcjgcj{}" . format('bread', 'butter'))
print( "{1}jghcjgcj{0}" . format('bread', 'butter'))
# Out:
# breadjghcjgcjbutter
# butterjghcjgcjbread
